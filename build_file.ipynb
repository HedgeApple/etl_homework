# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv('homework.csv')

# %%
df.head()
# Out:
#   item number           upc  new item system creation date  min order qty  \
# 0         203  8.109370e+11       NaN               7/7/15              1
# 1         205  8.109370e+11       NaN               7/7/15              1
# 2         208  8.109370e+11       NaN               7/7/15              1
# 3         210  8.109370e+11       NaN               7/7/15              1
# 4         217  8.109370e+11       NaN               7/7/15              1
#
#   sales uom wholesale ($) map ($) msrp ($)  \
# 0      Each         228.0   304.0  $456.00
# 1      Each         229.5   306.0  $459.00
# 2      Each         201.0   268.0  $402.00
# 3      Each         151.5   202.0  $303.00
# 4      Each         219.0   292.0  $438.00
#
#                                          description long description  \
# 0          White Obelisk Table Lamp With Night Light              NaN
# 1  Antiqued Porcelain Table Lamp In Celadon Crack...              NaN
# 2                 Bisque Ceramic Table Lamp In Taupe              NaN
# 3       Recycled Fluted Glass Urn Table Lamp In Blue              NaN
# 4          Fluted Mercury Glass Table Lamp In Silver              NaN
#
#              brand    item category   item type outdoor  item width (inches)  \
# 0  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 1  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 2  Dimond Lighting  Indoor Lighting  Table Lamp      No                 10.0
# 3  Dimond Lighting  Indoor Lighting  Table Lamp      No                 20.0
# 4  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
#
#    item depth (inches)  item height (inches)  item diameter (inches)  \
# 0                 18.0                  36.0                    18.0
# 1                 18.0                  31.0                    18.0
# 2                 10.0                  27.0                    10.0
# 3                 20.0                  25.0                    20.0
# 4                 18.0                  34.0                    18.0
#
#    item weight (pounds) multi-piece dimension 1 (inches)  \
# 0                   6.0                              NaN
# 1                  12.0                              NaN
# 2                   7.0                              NaN
# 3                   8.0                              NaN
# 4                  10.0                              NaN
#
#   multi-piece dimension 2 (inches) multi-piece dimension 3 (inches)  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   multi-piece dimension 4 (inches)           item materials  \
# 0                              NaN                    Glass
# 1                              NaN                  Ceramic
# 2                              NaN                  Ceramic
# 3                              NaN  Recycled Glass, Acrylic
# 4                              NaN                    Glass
#
#   primary color family item finish item finish 1 item finish 2 item finish 3  \
# 0                  NaN       White         White           NaN           NaN
# 1                  NaN     Celadon       Celadon           NaN           NaN
# 2                  NaN       Taupe         Taupe           NaN           NaN
# 3                  NaN        Blue          Blue           NaN           NaN
# 4                  NaN      Silver        Silver           NaN           NaN
#
#    primary image filename                                  url primary image  \
# 0                     NaN                                                NaN
# 1                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url alternate image 1 url alternate image 2 url alternate image 3  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 4 url alternate image 5 url alternate image 6  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 7 url alternate image 8  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#                             url room setting image 1 url room setting image 2  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...                      NaN
# 4                                                NaN                      NaN
#
#   url room setting image 3 url drawing  url interactive 360 image  \
# 0                      NaN         NaN                        NaN
# 1                      NaN         NaN                        NaN
# 2                      NaN         NaN                        NaN
# 3                      NaN         NaN                        NaN
# 4                      NaN         NaN                        NaN
#
#   url animated gif                                  url product sheet  \
# 0              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url instruction sheet  url marketing sheet 1  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#                           url california label (jpg)  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#                           url california label (pdf)             item style  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
#
#        item substyle item substyle 2 item collection licensed by  \
# 0        Luxe / Glam             NaN         Obelisk         NaN
# 1  Country / Cottage             NaN       Porcelain         NaN
# 2       Scandinavian             NaN         Ceramic         NaN
# 3    Coastal / Beach             NaN  Recycled Glass         NaN
# 4        Luxe / Glam             NaN   Mercury Glass         NaN
#
#    carton count truck only  carton 1 width (inches)  carton 1 length (inches)  \
# 0           1.0         No                     19.0                      19.0
# 1           1.0         No                     18.2                      21.0
# 2           1.0         No                     12.0                      27.7
# 3           1.0         No                     21.0                      21.0
# 4           1.0         No                     18.2                      25.9
#
#    carton 1 height (inches)  carton 1 weight (pounds)  \
# 0                      34.0                      10.0
# 1                      18.2                      14.0
# 2                      12.0                      10.0
# 3                      23.0                      10.0
# 4                      18.2                      12.0
#
#    carton 1 volume (cubic feet)  carton 2 width (inches)  \
# 0                          7.10                      NaN
# 1                          4.03                      NaN
# 2                          2.31                      NaN
# 3                          5.87                      NaN
# 4                          4.96                      NaN
#
#    carton 2 length (inches)  carton 2 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 2 weight (pounds)  carton2volumecubicfeet  carton 3 width (inches)  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
#    carton 3 length (inches)  carton 3 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 3 weight (pounds)  carton 3 volume (cubic feet) ada compliant  \
# 0                       NaN                           NaN           NaN
# 1                       NaN                           NaN           NaN
# 2                       NaN                           NaN           NaN
# 3                       NaN                           NaN           NaN
# 4                       NaN                           NaN           NaN
#
#   available with eef conversion kit option title 24 compliant safety rating  \
# 0                 No                    No                NaN            UL
# 1                 No                    No                NaN            UL
# 2                 No                    No                NaN            UL
# 3                 No                    No                NaN            UL
# 4                 No                    No                NaN            UL
#
#   certified damp/wet  bulb 1 count  bulb 1 wattage bulb 1 type bulb 1 base  \
# 0                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 1                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 2                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 3                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 4                NaN           1.0           100.0   A21 3-Way  E26 Medium
#
#   bulb 1 included  bulb 2 count  bulb 2 wattage bulb 2 type bulb 2 base  \
# 0              No           NaN             NaN         NaN         NaN
# 1              No           NaN             NaN         NaN         NaN
# 2              No           NaN             NaN         NaN         NaN
# 3              No           NaN             NaN         NaN         NaN
# 4              No           NaN             NaN         NaN         NaN
#
#   bulb 2 included  led  total lumens color temperature  cri  voltage  \
# 0             NaN  NaN           NaN               NaN  NaN      NaN
# 1             NaN  NaN           NaN               NaN  NaN      NaN
# 2             NaN  NaN           NaN               NaN  NaN      NaN
# 3             NaN  NaN           NaN               NaN  NaN      NaN
# 4             NaN  NaN           NaN               NaN  NaN      NaN
#
#   switch type dimmable lamp base dimensions (inches)  \
# 0       3-Way      NaN                           NaN
# 1       3-Way      NaN                           NaN
# 2       3-Way      NaN                           NaN
# 3       3-Way      NaN                           NaN
# 4       3-Way      NaN                           NaN
#
#   backplate/canopy dimensions (inches) extension rods (inches)  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
#
#    min overall height (inches)  max overall height (inches)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    min extension (inches)  max extension (inches)  hcwo (inches)  \
# 0                     NaN                     NaN            NaN
# 1                     NaN                     NaN            NaN
# 2                     NaN                     NaN            NaN
# 3                     NaN                     NaN            NaN
# 4                     NaN                     NaN            NaN
#
#              shade/glass description shade/glass materials shade/glass finish  \
# 0  Round Hardback White Fabric Shade                Fabric              White
# 1        Round Hardback Burlap Shade                Burlap          Off-White
# 2         Round Hardback Linen Shade                 Linen              Brown
# 3  Round Hardback White Fabric Shade                Fabric              White
# 4  Round Hardback White Fabric Shade                Fabric              White
#
#    shade/glass width  shade/glass width at top (inches)  \
# 0                NaN                               16.0
# 1                NaN                               16.0
# 2                NaN                               10.0
# 3                NaN                               14.0
# 4                NaN                               16.0
#
#    shade/glass width at bottom (inches)  shade/glass height (inches)  \
# 0                                  18.0                         11.0
# 1                                  18.0                         11.0
# 2                                  10.0                         16.0
# 3                                  20.0                         11.0
# 4                                  18.0                         11.0
#
#   shade shape harp/spider cord color  cord length (inches)  \
# 0         NaN         NaN        NaN                  66.0
# 1         NaN         NaN        NaN                  66.0
# 2         NaN         NaN        NaN                  66.0
# 3         NaN         NaN        NaN                  66.0
# 4         NaN         NaN        NaN                  66.0
#
#    chain length (inches)  chain price ($) replacement glass price ($)  \
# 0                    NaN              NaN                         NaN
# 1                    NaN              NaN                         NaN
# 2                    NaN              NaN                         NaN
# 3                    NaN              NaN                         NaN
# 4                    NaN              NaN                         NaN
#
#    replacement crystal price ($)  mirror width (inches)  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#    mirror height (inches)  drawer count drawer 1 interior dimensions (inches)  \
# 0                     NaN           NaN                                   NaN
# 1                     NaN           NaN                                   NaN
# 2                     NaN           NaN                                   NaN
# 3                     NaN           NaN                                   NaN
# 4                     NaN           NaN                                   NaN
#
#   drawer 2 interior dimensions (inches) drawer 3 interior dimensions (inches)  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    furniture arm height (inches)  furniture seat height (inches)  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   furniture seat dimensions (inches)  furniture weight capacity (pounds)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   country of origin  primary catalog primary catalog page related items  \
# 0             China    ELK Home 2019                  529           NaN
# 1             China  Lamp Works 2016                   28           NaN
# 2             China  Lamp Works 2016                   36           NaN
# 3             China    ELK Home 2019                  517           NaN
# 4             China  Lamp Works 2016                   41           NaN
#
#                                            brand bio  \
# 0  Dimond Lighting is an award-winning designer a...
# 1  Dimond Lighting is an award-winning designer a...
# 2  Dimond Lighting is an award-winning designer a...
# 3  Dimond Lighting is an award-winning designer a...
# 4  Dimond Lighting is an award-winning designer a...
#
#                                         helpful tips    selling point 1  \
# 0  When choosing a table lamp it is important to ...   8-Inch wide base
# 1  When choosing a table lamp it is important to ...  12-Inch wide base
# 2  When choosing a table lamp it is important to ...  10-Inch wide base
# 3  When choosing a table lamp it is important to ...  14-Inch wide base
# 4  When choosing a table lamp it is important to ...   9-Inch wide base
#
#   selling point 2 selling point 3 selling point 4 selling point 5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    selling point 6  selling point 7  selling point 8  selling point 9  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    selling point 10 record status
# 0               NaN        Active
# 1               NaN        Active
# 2               NaN        Active
# 3               NaN        Active
# 4               NaN        Active

# %%
example = pd.read_csv('example.csv')

# %%
example
# Out:
#   manufacturer_sku            ean13  weight  length  width  height  prop_65  \
# 0        3129-1149  081-800803392-6     3.3     2.8   23.6    16.1     True
# 1         8903-071  081-800803319-3     1.5     3.0    5.0     7.0     True
# 2        7011-1034  081-800803463-3    63.0    16.0   32.0    30.0     True
#
#    cost_price  min_price  made_to_order product__product_class__name  \
# 0       49.80      89.64          False            Decorative Accent
# 1       33.20       0.00          False            Decorative Accent
# 2      322.66       0.00          False                    Furniture
#
#   product__brand__name                  product__title  \
# 0      Dimond Lighting  Ascencio Hinged Candle Holders
# 1      Dimond Lighting             Bambloo Photo Frame
# 2      Dimond Lighting           Bedford Bedside Table
#
#                                 product__description  \
# 0  A ascencio hinged candle holders in a rust fin...
# 1  A navy blue bambloo small photo frame made of ...
# 2  A dove white and gray bedford fabric wrapped 2...
#
#              product__bullets__0  product__bullets__1  product__bullets__2  \
# 0                            NaN                  NaN                  NaN
# 1                            NaN                  NaN                  NaN
# 2  Wrapped in Cotton, Polyester.                  NaN                  NaN
#
#    product__bullets__3  product__bullets__4  product__bullets__5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
#
#    product__bullets__6 product__configuration__codes  \
# 0                  NaN                        finish
# 1                  NaN                        finish
# 2                  NaN                        finish
#
#    product__multipack_quantity product__country_of_origin__alpha_3  \
# 0                            1                                 CHN
# 1                            1                                 IND
# 2                            1                                 IDN
#
#   product__parent_sku  attrib__arm_height  attrib__assembly_required  \
# 0           O-1000929                 NaN                        NaN
# 1           O-1000935                 NaN                        NaN
# 2           O-1000940                 NaN                        NaN
#
#    attrib__back_material  attrib__blade_finish  attrib__bulb_included  \
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
#
#    attrib__bulb_type  attrib__color  attrib__cord_length  attrib__design_id  \
# 0                NaN            NaN                  NaN                NaN
# 1                NaN            NaN                  NaN                NaN
# 2                NaN            NaN                  NaN                NaN
#
#    attrib__designer  attrib__distressed_finish  attrib__fill  \
# 0               NaN                        NaN           NaN
# 1               NaN                        NaN           NaN
# 2               NaN                        NaN           NaN
#
#      attrib__finish  attrib__frame_color  attrib__hardwire  attrib__kit  \
# 0              Rust                  NaN               NaN          NaN
# 1         Navy Blue                  NaN               NaN          NaN
# 2  Dove White, Gray                  NaN               NaN          NaN
#
#    attrib__leg_color  attrib__leg_finish                  attrib__material  \
# 0                NaN                 NaN                             Metal
# 1                NaN                 NaN                              Bone
# 2                NaN                 NaN  Mahogany, Wood Composite, Fabric
#
#    attrib__number_bulbs  attrib__orientation  attrib__outdoor_safe  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
#
#    attrib__pile_height  attrib__seat_depth  attrib__seat_height  \
# 0                  NaN                 NaN                  NaN
# 1                  NaN                 NaN                  NaN
# 2                  NaN                 NaN                  NaN
#
#    attrib__seat_width  attrib__shade attrib__size  attrib__switch_type  \
# 0                 NaN            NaN          NaN                  NaN
# 1                 NaN            NaN        Large                  NaN
# 2                 NaN            NaN          NaN                  NaN
#
#    attrib__ul_certified  attrib__warranty_years  attrib__wattage  \
# 0                   NaN                     NaN              NaN
# 1                   NaN                     NaN              NaN
# 2                   NaN                     NaN              NaN
#
#    attrib__weave  attrib__weight_capacity  boxes__0__weight  boxes__0__length  \
# 0            NaN                      NaN                 5                22
# 1            NaN                      NaN                 3                14
# 2            NaN                      NaN                63                18
#
#    boxes__0__height  boxes__0__width  boxes__1__weight  boxes__1__length  \
# 0                18               16               NaN               NaN
# 1                20               13               NaN               NaN
# 2                34               18               NaN               NaN
#
#    boxes__1__height  boxes__1__width  boxes__2__weight  boxes__2__length  \
# 0               NaN              NaN               NaN               NaN
# 1               NaN              NaN               NaN               NaN
# 2               NaN              NaN               NaN               NaN
#
#    boxes__2__height  boxes__2__width  boxes__3__weight  boxes__3__length  \
# 0               NaN              NaN               NaN               NaN
# 1               NaN              NaN               NaN               NaN
# 2               NaN              NaN               NaN               NaN
#
#    boxes__3__height  boxes__3__width               product__styles
# 0               NaN              NaN                        Modern
# 1               NaN              NaN    Coastal, Eclectic & Global
# 2               NaN              NaN  Coastal, Cottage & Farmhouse

# %%
df
# Out:
#        item number             upc  new item system creation date  \
# 0              203  810937002035.0       NaN           2015-07-07
# 1              205  810937002059.0       NaN           2015-07-07
# 2              208  810937002080.0       NaN           2015-07-07
# 3              210  810937002103.0       NaN           2015-07-07
# 4              217  810937002172.0       NaN           2015-07-07
# ...            ...             ...       ...                  ...
# 6665  MW5000C-0046  811137021185.0       NaN           2014-10-10
# 6666  MW5600B-0070  811137021246.0       NaN           2014-10-10
# 6667  MW6300A-0043  811137021284.0       NaN           2014-10-10
# 6668  MW6300B-0043  811137021291.0       NaN           2014-10-10
# 6669   MW7888-0018  811137021338.0       NaN           2014-10-10
#
#       min order qty sales uom wholesale ($) map ($) msrp ($)  \
# 0                 1      Each        228.00  304.00   456.00
# 1                 1      Each        229.50  306.00   459.00
# 2                 1      Each        201.00  268.00   402.00
# 3                 1      Each        151.50  202.00   303.00
# 4                 1      Each        219.00  292.00   438.00
# ...             ...       ...           ...     ...      ...
# 6665              1      Each         90.00  162.00   270.00
# 6666              1      Each        250.00  450.00   750.00
# 6667              1      Each        190.00  342.00   570.00
# 6668              1      Each        150.00  270.00   450.00
# 6669              1      Each        175.00  315.00   525.00
#
#                                             description  \
# 0             White Obelisk Table Lamp With Night Light
# 1     Antiqued Porcelain Table Lamp In Celadon Crack...
# 2                    Bisque Ceramic Table Lamp In Taupe
# 3          Recycled Fluted Glass Urn Table Lamp In Blue
# 4             Fluted Mercury Glass Table Lamp In Silver
# ...                                                 ...
# 6665                           Angled Carved Wood Frame
# 6666                      French Versailles Masterpiece
# 6667              Victorian Carved Wood, Beveled Mirror
# 6668              Victorian Carved Wood, Beveled Mirror
# 6669  Free Formed Oval and Round Mirror With a Centr...
#
#                                        long description            brand  \
# 0                                                   NaN  Dimond Lighting
# 1                                                   NaN  Dimond Lighting
# 2                                                   NaN  Dimond Lighting
# 3                                                   NaN  Dimond Lighting
# 4                                                   NaN  Dimond Lighting
# ...                                                 ...              ...
# 6665  An angled carved wood frame gives visual depth...         Sterling
# 6666  Steeped in tradition with intricate detail on ...         Sterling
# 6667  The Victorian carved wood pattern is enriched ...         Sterling
# 6668  The Victorian carved wood pattern is enriched ...         Sterling
# 6669  Captured circles arranged in a free-form patte...         Sterling
#
#         item category   item type outdoor  item width (inches)  \
# 0     Indoor Lighting  Table Lamp      No                 18.0
# 1     Indoor Lighting  Table Lamp      No                 18.0
# 2     Indoor Lighting  Table Lamp      No                 10.0
# 3     Indoor Lighting  Table Lamp      No                 20.0
# 4     Indoor Lighting  Table Lamp      No                 18.0
# ...               ...         ...     ...                  ...
# 6665       Wall Decor      Mirror      No                 29.0
# 6666       Wall Decor      Mirror      No                 48.3
# 6667       Wall Decor      Mirror      No                 35.9
# 6668       Wall Decor      Mirror      No                 17.4
# 6669       Wall Decor      Mirror      No                 31.5
#
#       item depth (inches)  item height (inches)  item diameter (inches)  \
# 0                    18.0                  36.0                    18.0
# 1                    18.0                  31.0                    18.0
# 2                    10.0                  27.0                    10.0
# 3                    20.0                  25.0                    20.0
# 4                    18.0                  34.0                    18.0
# ...                   ...                   ...                     ...
# 6665                  2.0                  41.0                     NaN
# 6666                  2.0                  60.3                     NaN
# 6667                  1.0                  46.4                     NaN
# 6668                  1.0                  52.4                     NaN
# 6669                  1.0                  31.5                     NaN
#
#       item weight (pounds) multi-piece dimension 1 (inches)  \
# 0                      6.0                              NaN
# 1                     12.0                              NaN
# 2                      7.0                              NaN
# 3                      8.0                              NaN
# 4                     10.0                              NaN
# ...                    ...                              ...
# 6665                  16.6                              NaN
# 6666                  58.3                              NaN
# 6667                  25.3                              NaN
# 6668                  15.4                              NaN
# 6669                  16.3                              NaN
#
#      multi-piece dimension 2 (inches) multi-piece dimension 3 (inches)  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 6665                              NaN                              NaN
# 6666                              NaN                              NaN
# 6667                              NaN                              NaN
# 6668                              NaN                              NaN
# 6669                              NaN                              NaN
#
#      multi-piece dimension 4 (inches)           item materials  \
# 0                                 NaN                    Glass
# 1                                 NaN                  Ceramic
# 2                                 NaN                  Ceramic
# 3                                 NaN  Recycled Glass, Acrylic
# 4                                 NaN                    Glass
# ...                               ...                      ...
# 6665                              NaN                      NaN
# 6666                              NaN                      NaN
# 6667                              NaN                      NaN
# 6668                              NaN                      NaN
# 6669                              NaN                      NaN
#
#      primary color family                   item finish  item finish 1  \
# 0                     NaN                         White          White
# 1                     NaN                       Celadon        Celadon
# 2                     NaN                         Taupe          Taupe
# 3                     NaN                          Blue           Blue
# 4                     NaN                        Silver         Silver
# ...                   ...                           ...            ...
# 6665                  NaN            Bronze, Roman Gold         Bronze
# 6666                  NaN                 Ebony, Walnut          Ebony
# 6667                  NaN  Medium Bronze, Venetian Gold  Medium Bronze
# 6668                  NaN  Medium Bronze, Venetian Gold  Medium Bronze
# 6669                  NaN           Black Trace, Silver    Black Trace
#
#       item finish 2 item finish 3  primary image filename  \
# 0               NaN           NaN                     NaN
# 1               NaN           NaN                     NaN
# 2               NaN           NaN                     NaN
# 3               NaN           NaN                     NaN
# 4               NaN           NaN                     NaN
# ...             ...           ...                     ...
# 6665     Roman Gold           NaN                     NaN
# 6666         Walnut           NaN                     NaN
# 6667  Venetian Gold           NaN                     NaN
# 6668  Venetian Gold           NaN                     NaN
# 6669         Silver           NaN                     NaN
#
#                                       url primary image url alternate image 1  \
# 0                                                   NaN                   NaN
# 1     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 2     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 3     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 4     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# ...                                                 ...                   ...
# 6665  https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 6666  https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 6667  https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 6668                                                NaN                   NaN
# 6669                                                NaN                   NaN
#
#      url alternate image 2 url alternate image 3 url alternate image 4  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 6665                   NaN                   NaN                   NaN
# 6666                   NaN                   NaN                   NaN
# 6667                   NaN                   NaN                   NaN
# 6668                   NaN                   NaN                   NaN
# 6669                   NaN                   NaN                   NaN
#
#      url alternate image 5 url alternate image 6 url alternate image 7  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 6665                   NaN                   NaN                   NaN
# 6666                   NaN                   NaN                   NaN
# 6667                   NaN                   NaN                   NaN
# 6668                   NaN                   NaN                   NaN
# 6669                   NaN                   NaN                   NaN
#
#      url alternate image 8                           url room setting image 1  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 6665                   NaN                                                NaN
# 6666                   NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6667                   NaN                                                NaN
# 6668                   NaN                                                NaN
# 6669                   NaN                                                NaN
#
#      url room setting image 2 url room setting image 3 url drawing  \
# 0                         NaN                      NaN         NaN
# 1                         NaN                      NaN         NaN
# 2                         NaN                      NaN         NaN
# 3                         NaN                      NaN         NaN
# 4                         NaN                      NaN         NaN
# ...                       ...                      ...         ...
# 6665                      NaN                      NaN         NaN
# 6666                      NaN                      NaN         NaN
# 6667                      NaN                      NaN         NaN
# 6668                      NaN                      NaN         NaN
# 6669                      NaN                      NaN         NaN
#
#       url interactive 360 image url animated gif  \
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN              NaN
# 3                           NaN              NaN
# 4                           NaN              NaN
# ...                         ...              ...
# 6665                        NaN              NaN
# 6666                        NaN              NaN
# 6667                        NaN              NaN
# 6668                        NaN              NaN
# 6669                        NaN              NaN
#
#                                       url product sheet url instruction sheet  \
# 0     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 1     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 2     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 3     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# 4     https://s3-us-west-2.amazonaws.com/elk-assets/...                   NaN
# ...                                                 ...                   ...
# 6665                                                NaN                   NaN
# 6666                                                NaN                   NaN
# 6667                                                NaN                   NaN
# 6668                                                NaN                   NaN
# 6669                                                NaN                   NaN
#
#       url marketing sheet 1  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 6665                    NaN
# 6666                    NaN
# 6667                    NaN
# 6668                    NaN
# 6669                    NaN
#
#                              url california label (jpg)  \
# 0     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4     https://s3-us-west-2.amazonaws.com/elk-assets/...
# ...                                                 ...
# 6665  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6666  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6667  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6668  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6669  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#                              url california label (pdf)  \
# 0     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3     https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4     https://s3-us-west-2.amazonaws.com/elk-assets/...
# ...                                                 ...
# 6665  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6666  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6667  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6668  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 6669  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#                  item style      item substyle item substyle 2  \
# 0     Modern / Contemporary        Luxe / Glam             NaN
# 1               Traditional  Country / Cottage             NaN
# 2     Modern / Contemporary       Scandinavian             NaN
# 3               Traditional    Coastal / Beach             NaN
# 4     Modern / Contemporary        Luxe / Glam             NaN
# ...                     ...                ...             ...
# 6665           Transitional   Modern Farmhouse  French Country
# 6666                    NaN                NaN             NaN
# 6667           Transitional   Modern Farmhouse  French Country
# 6668           Transitional   Modern Farmhouse  French Country
# 6669  Modern / Contemporary              Retro     Luxe / Glam
#
#      item collection licensed by  carton count truck only  \
# 0            Obelisk         NaN           1.0         No
# 1          Porcelain         NaN           1.0         No
# 2            Ceramic         NaN           1.0         No
# 3     Recycled Glass         NaN           1.0         No
# 4      Mercury Glass         NaN           1.0         No
# ...              ...         ...           ...        ...
# 6665         Everett         NaN           1.0         No
# 6666       Colebrook         NaN           1.0        Yes
# 6667         Glenroy         NaN           1.0         No
# 6668         Glenroy         NaN           1.0         No
# 6669          Orveta         NaN           1.0         No
#
#       carton 1 width (inches)  carton 1 length (inches)  \
# 0                        19.0                      19.0
# 1                        18.2                      21.0
# 2                        12.0                      27.7
# 3                        21.0                      21.0
# 4                        18.2                      25.9
# ...                       ...                       ...
# 6665                     32.7                      44.7
# 6666                     52.0                      64.0
# 6667                     39.7                      50.2
# 6668                     21.2                      56.2
# 6669                     34.3                      34.3
#
#       carton 1 height (inches)  carton 1 weight (pounds)  \
# 0                         34.0                      10.0
# 1                         18.2                      14.0
# 2                         12.0                      10.0
# 3                         23.0                      10.0
# 4                         18.2                      12.0
# ...                        ...                       ...
# 6665                       3.1                      19.4
# 6666                       3.7                      64.7
# 6667                       3.3                      29.1
# 6668                       3.3                      17.8
# 6669                       3.2                      19.4
#
#       carton 1 volume (cubic feet)  carton 2 width (inches)  \
# 0                             7.10                      NaN
# 1                             4.03                      NaN
# 2                             2.31                      NaN
# 3                             5.87                      NaN
# 4                             4.96                      NaN
# ...                            ...                      ...
# 6665                          2.62                      NaN
# 6666                          7.13                      NaN
# 6667                          3.81                      NaN
# 6668                          2.28                      NaN
# 6669                          2.18                      NaN
#
#       carton 2 length (inches)  carton 2 height (inches)  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 6665                       NaN                       NaN
# 6666                       NaN                       NaN
# 6667                       NaN                       NaN
# 6668                       NaN                       NaN
# 6669                       NaN                       NaN
#
#       carton 2 weight (pounds)  carton2volumecubicfeet  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 6665                       NaN                     NaN
# 6666                       NaN                     NaN
# 6667                       NaN                     NaN
# 6668                       NaN                     NaN
# 6669                       NaN                     NaN
#
#       carton 3 width (inches)  carton 3 length (inches)  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 6665                      NaN                       NaN
# 6666                      NaN                       NaN
# 6667                      NaN                       NaN
# 6668                      NaN                       NaN
# 6669                      NaN                       NaN
#
#       carton 3 height (inches)  carton 3 weight (pounds)  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 6665                       NaN                       NaN
# 6666                       NaN                       NaN
# 6667                       NaN                       NaN
# 6668                       NaN                       NaN
# 6669                       NaN                       NaN
#
#       carton 3 volume (cubic feet) ada compliant available with eef  \
# 0                              NaN           NaN                 No
# 1                              NaN           NaN                 No
# 2                              NaN           NaN                 No
# 3                              NaN           NaN                 No
# 4                              NaN           NaN                 No
# ...                            ...           ...                ...
# 6665                           NaN           NaN                NaN
# 6666                           NaN           NaN                NaN
# 6667                           NaN           NaN                NaN
# 6668                           NaN           NaN                NaN
# 6669                           NaN           NaN                NaN
#
#      conversion kit option title 24 compliant safety rating  \
# 0                       No                NaN            UL
# 1                       No                NaN            UL
# 2                       No                NaN            UL
# 3                       No                NaN            UL
# 4                       No                NaN            UL
# ...                    ...                ...           ...
# 6665                   NaN                NaN           NaN
# 6666                   NaN                NaN           NaN
# 6667                   NaN                NaN           NaN
# 6668                   NaN                NaN           NaN
# 6669                   NaN                NaN           NaN
#
#      certified damp/wet  bulb 1 count  bulb 1 wattage bulb 1 type bulb 1 base  \
# 0                   NaN           1.0           100.0   A21 3-Way  E26 Medium
# 1                   NaN           1.0           100.0   A21 3-Way  E26 Medium
# 2                   NaN           1.0           100.0   A21 3-Way  E26 Medium
# 3                   NaN           1.0           100.0   A21 3-Way  E26 Medium
# 4                   NaN           1.0           100.0   A21 3-Way  E26 Medium
# ...                 ...           ...             ...         ...         ...
# 6665                NaN           NaN             NaN         NaN         NaN
# 6666                NaN           NaN             NaN         NaN         NaN
# 6667                NaN           NaN             NaN         NaN         NaN
# 6668                NaN           NaN             NaN         NaN         NaN
# 6669                NaN           NaN             NaN         NaN         NaN
#
#      bulb 1 included  bulb 2 count  bulb 2 wattage bulb 2 type bulb 2 base  \
# 0                 No           NaN             NaN         NaN         NaN
# 1                 No           NaN             NaN         NaN         NaN
# 2                 No           NaN             NaN         NaN         NaN
# 3                 No           NaN             NaN         NaN         NaN
# 4                 No           NaN             NaN         NaN         NaN
# ...              ...           ...             ...         ...         ...
# 6665             NaN           NaN             NaN         NaN         NaN
# 6666             NaN           NaN             NaN         NaN         NaN
# 6667             NaN           NaN             NaN         NaN         NaN
# 6668             NaN           NaN             NaN         NaN         NaN
# 6669             NaN           NaN             NaN         NaN         NaN
#
#      bulb 2 included  led  total lumens color temperature  cri  voltage  \
# 0                NaN  NaN           NaN               NaN  NaN      NaN
# 1                NaN  NaN           NaN               NaN  NaN      NaN
# 2                NaN  NaN           NaN               NaN  NaN      NaN
# 3                NaN  NaN           NaN               NaN  NaN      NaN
# 4                NaN  NaN           NaN               NaN  NaN      NaN
# ...              ...  ...           ...               ...  ...      ...
# 6665             NaN  NaN           NaN               NaN  NaN      NaN
# 6666             NaN  NaN           NaN               NaN  NaN      NaN
# 6667             NaN  NaN           NaN               NaN  NaN      NaN
# 6668             NaN  NaN           NaN               NaN  NaN      NaN
# 6669             NaN  NaN           NaN               NaN  NaN      NaN
#
#      switch type dimmable lamp base dimensions (inches)  \
# 0          3-Way      NaN                           NaN
# 1          3-Way      NaN                           NaN
# 2          3-Way      NaN                           NaN
# 3          3-Way      NaN                           NaN
# 4          3-Way      NaN                           NaN
# ...          ...      ...                           ...
# 6665         NaN      NaN                           NaN
# 6666         NaN      NaN                           NaN
# 6667         NaN      NaN                           NaN
# 6668         NaN      NaN                           NaN
# 6669         NaN      NaN                           NaN
#
#      backplate/canopy dimensions (inches) extension rods (inches)  \
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                                     NaN                     NaN
# 3                                     NaN                     NaN
# 4                                     NaN                     NaN
# ...                                   ...                     ...
# 6665                                  NaN                     NaN
# 6666                                  NaN                     NaN
# 6667                                  NaN                     NaN
# 6668                                  NaN                     NaN
# 6669                                  NaN                     NaN
#
#       min overall height (inches)  max overall height (inches)  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 6665                          NaN                          NaN
# 6666                          NaN                          NaN
# 6667                          NaN                          NaN
# 6668                          NaN                          NaN
# 6669                          NaN                          NaN
#
#       min extension (inches)  max extension (inches)  hcwo (inches)  \
# 0                        NaN                     NaN            NaN
# 1                        NaN                     NaN            NaN
# 2                        NaN                     NaN            NaN
# 3                        NaN                     NaN            NaN
# 4                        NaN                     NaN            NaN
# ...                      ...                     ...            ...
# 6665                     NaN                     NaN            NaN
# 6666                     NaN                     NaN            NaN
# 6667                     NaN                     NaN            NaN
# 6668                     NaN                     NaN            NaN
# 6669                     NaN                     NaN            NaN
#
#                 shade/glass description shade/glass materials  \
# 0     Round Hardback White Fabric Shade                Fabric
# 1           Round Hardback Burlap Shade                Burlap
# 2            Round Hardback Linen Shade                 Linen
# 3     Round Hardback White Fabric Shade                Fabric
# 4     Round Hardback White Fabric Shade                Fabric
# ...                                 ...                   ...
# 6665                                NaN                   NaN
# 6666                                NaN                   NaN
# 6667                                NaN                   NaN
# 6668                                NaN                   NaN
# 6669                                NaN                   NaN
#
#      shade/glass finish  shade/glass width  shade/glass width at top (inches)  \
# 0                 White                NaN                               16.0
# 1             Off-White                NaN                               16.0
# 2                 Brown                NaN                               10.0
# 3                 White                NaN                               14.0
# 4                 White                NaN                               16.0
# ...                 ...                ...                                ...
# 6665       Bronze Tones                NaN                                NaN
# 6666               Wood                NaN                                NaN
# 6667       Bronze Tones                NaN                                NaN
# 6668       Bronze Tones                NaN                                NaN
# 6669            Silvers                NaN                                NaN
#
#       shade/glass width at bottom (inches)  shade/glass height (inches)  \
# 0                                     18.0                         11.0
# 1                                     18.0                         11.0
# 2                                     10.0                         16.0
# 3                                     20.0                         11.0
# 4                                     18.0                         11.0
# ...                                    ...                          ...
# 6665                                   NaN                          NaN
# 6666                                   NaN                          NaN
# 6667                                   NaN                          NaN
# 6668                                   NaN                          NaN
# 6669                                   NaN                          NaN
#
#      shade shape harp/spider cord color  cord length (inches)  \
# 0            NaN         NaN        NaN                  66.0
# 1            NaN         NaN        NaN                  66.0
# 2            NaN         NaN        NaN                  66.0
# 3            NaN         NaN        NaN                  66.0
# 4            NaN         NaN        NaN                  66.0
# ...          ...         ...        ...                   ...
# 6665         NaN         NaN        NaN                   NaN
# 6666         NaN         NaN        NaN                   NaN
# 6667         NaN         NaN        NaN                   NaN
# 6668         NaN         NaN        NaN                   NaN
# 6669         NaN         NaN        NaN                   NaN
#
#       chain length (inches)  chain price ($) replacement glass price ($)  \
# 0                       NaN              NaN                         NaN
# 1                       NaN              NaN                         NaN
# 2                       NaN              NaN                         NaN
# 3                       NaN              NaN                         NaN
# 4                       NaN              NaN                         NaN
# ...                     ...              ...                         ...
# 6665                    NaN              NaN                         NaN
# 6666                    NaN              NaN                         NaN
# 6667                    NaN              NaN                         NaN
# 6668                    NaN              NaN                         NaN
# 6669                    NaN              NaN                         NaN
#
#       replacement crystal price ($)  mirror width (inches)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 6665                            NaN                    NaN
# 6666                            NaN                    NaN
# 6667                            NaN                    NaN
# 6668                            NaN                    NaN
# 6669                            NaN                    NaN
#
#       mirror height (inches)  drawer count  \
# 0                        NaN           NaN
# 1                        NaN           NaN
# 2                        NaN           NaN
# 3                        NaN           NaN
# 4                        NaN           NaN
# ...                      ...           ...
# 6665                     NaN           NaN
# 6666                     NaN           NaN
# 6667                     NaN           NaN
# 6668                     NaN           NaN
# 6669                     NaN           NaN
#
#      drawer 1 interior dimensions (inches)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 6665                                   NaN
# 6666                                   NaN
# 6667                                   NaN
# 6668                                   NaN
# 6669                                   NaN
#
#      drawer 2 interior dimensions (inches)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 6665                                   NaN
# 6666                                   NaN
# 6667                                   NaN
# 6668                                   NaN
# 6669                                   NaN
#
#      drawer 3 interior dimensions (inches)  furniture arm height (inches)  \
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2                                      NaN                            NaN
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN
# ...                                    ...                            ...
# 6665                                   NaN                            NaN
# 6666                                   NaN                            NaN
# 6667                                   NaN                            NaN
# 6668                                   NaN                            NaN
# 6669                                   NaN                            NaN
#
#       furniture seat height (inches) furniture seat dimensions (inches)  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# ...                              ...                                ...
# 6665                             NaN                                NaN
# 6666                             NaN                                NaN
# 6667                             NaN                                NaN
# 6668                             NaN                                NaN
# 6669                             NaN                                NaN
#
#       furniture weight capacity (pounds) country of origin  \
# 0                                    NaN             China
# 1                                    NaN             China
# 2                                    NaN             China
# 3                                    NaN             China
# 4                                    NaN             China
# ...                                  ...               ...
# 6665                                 NaN             China
# 6666                                 NaN             China
# 6667                                 NaN             China
# 6668                                 NaN             China
# 6669                                 NaN             China
#
#           primary catalog primary catalog page related items  \
# 0           ELK Home 2019                  529           NaN
# 1         Lamp Works 2016                   28           NaN
# 2         Lamp Works 2016                   36           NaN
# 3           ELK Home 2019                  517           NaN
# 4         Lamp Works 2016                   41           NaN
# ...                   ...                  ...           ...
# 6665  Mirror Masters 1114                  123           NaN
# 6666  Mirror Masters 1114                  187           NaN
# 6667  Mirror Masters 1114                  119           NaN
# 6668  Mirror Masters 1114                  185           NaN
# 6669  Mirror Masters 1114                   45           NaN
#
#                                               brand bio  \
# 0     Dimond Lighting is an award-winning designer a...
# 1     Dimond Lighting is an award-winning designer a...
# 2     Dimond Lighting is an award-winning designer a...
# 3     Dimond Lighting is an award-winning designer a...
# 4     Dimond Lighting is an award-winning designer a...
# ...                                                 ...
# 6665  Sterling is your go-to source for distinctive,...
# 6666  Sterling is your go-to source for distinctive,...
# 6667  Sterling is your go-to source for distinctive,...
# 6668  Sterling is your go-to source for distinctive,...
# 6669  Sterling is your go-to source for distinctive,...
#
#                                            helpful tips    selling point 1  \
# 0     When choosing a table lamp it is important to ...   8-Inch wide base
# 1     When choosing a table lamp it is important to ...  12-Inch wide base
# 2     When choosing a table lamp it is important to ...  10-Inch wide base
# 3     When choosing a table lamp it is important to ...  14-Inch wide base
# 4     When choosing a table lamp it is important to ...   9-Inch wide base
# ...                                                 ...                ...
# 6665  When hanging mirrors, consider placing a mirro...                NaN
# 6666  When hanging mirrors, consider placing a mirro...                NaN
# 6667  When hanging mirrors, consider placing a mirro...                NaN
# 6668  When hanging mirrors, consider placing a mirro...                NaN
# 6669  When hanging mirrors, consider placing a mirro...                NaN
#
#      selling point 2 selling point 3 selling point 4 selling point 5  \
# 0                NaN             NaN             NaN             NaN
# 1                NaN             NaN             NaN             NaN
# 2                NaN             NaN             NaN             NaN
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
# ...              ...             ...             ...             ...
# 6665             NaN             NaN             NaN             NaN
# 6666             NaN             NaN             NaN             NaN
# 6667             NaN             NaN             NaN             NaN
# 6668             NaN             NaN             NaN             NaN
# 6669             NaN             NaN             NaN             NaN
#
#       selling point 6  selling point 7  selling point 8  selling point 9  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 6665              NaN              NaN              NaN              NaN
# 6666              NaN              NaN              NaN              NaN
# 6667              NaN              NaN              NaN              NaN
# 6668              NaN              NaN              NaN              NaN
# 6669              NaN              NaN              NaN              NaN
#
#       selling point 10 record status
# 0                  NaN        Active
# 1                  NaN        Active
# 2                  NaN        Active
# 3                  NaN        Active
# 4                  NaN        Active
# ...                ...           ...
# 6665               NaN        Active
# 6666               NaN        Active
# 6667               NaN        Active
# 6668               NaN        Active
# 6669               NaN        Active
#
# [6670 rows x 146 columns]

# %%
# df.columns.to_list()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6670 entries, 0 to 6669
# Columns: 146 entries, item number to record status
# dtypes: float64(56), int64(1), object(89)
# memory usage: 7.4+ MB

# %%
# df.dtypes.head(50)

# %% [markdown]
# ## 1. Date transform to ISO 8601 (yyyy-mm-dd)

# %%
df['system creation date'] = pd.to_datetime(df['system creation date'])

# %%
df.head()
# Out:
#   item number           upc  new item system creation date  min order qty  \
# 0         203  8.109370e+11       NaN           2015-07-07              1
# 1         205  8.109370e+11       NaN           2015-07-07              1
# 2         208  8.109370e+11       NaN           2015-07-07              1
# 3         210  8.109370e+11       NaN           2015-07-07              1
# 4         217  8.109370e+11       NaN           2015-07-07              1
#
#   sales uom wholesale ($) map ($) msrp ($)  \
# 0      Each         228.0   304.0  $456.00
# 1      Each         229.5   306.0  $459.00
# 2      Each         201.0   268.0  $402.00
# 3      Each         151.5   202.0  $303.00
# 4      Each         219.0   292.0  $438.00
#
#                                          description long description  \
# 0          White Obelisk Table Lamp With Night Light              NaN
# 1  Antiqued Porcelain Table Lamp In Celadon Crack...              NaN
# 2                 Bisque Ceramic Table Lamp In Taupe              NaN
# 3       Recycled Fluted Glass Urn Table Lamp In Blue              NaN
# 4          Fluted Mercury Glass Table Lamp In Silver              NaN
#
#              brand    item category   item type outdoor  item width (inches)  \
# 0  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 1  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 2  Dimond Lighting  Indoor Lighting  Table Lamp      No                 10.0
# 3  Dimond Lighting  Indoor Lighting  Table Lamp      No                 20.0
# 4  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
#
#    item depth (inches)  item height (inches)  item diameter (inches)  \
# 0                 18.0                  36.0                    18.0
# 1                 18.0                  31.0                    18.0
# 2                 10.0                  27.0                    10.0
# 3                 20.0                  25.0                    20.0
# 4                 18.0                  34.0                    18.0
#
#    item weight (pounds) multi-piece dimension 1 (inches)  \
# 0                   6.0                              NaN
# 1                  12.0                              NaN
# 2                   7.0                              NaN
# 3                   8.0                              NaN
# 4                  10.0                              NaN
#
#   multi-piece dimension 2 (inches) multi-piece dimension 3 (inches)  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   multi-piece dimension 4 (inches)           item materials  \
# 0                              NaN                    Glass
# 1                              NaN                  Ceramic
# 2                              NaN                  Ceramic
# 3                              NaN  Recycled Glass, Acrylic
# 4                              NaN                    Glass
#
#   primary color family item finish item finish 1 item finish 2 item finish 3  \
# 0                  NaN       White         White           NaN           NaN
# 1                  NaN     Celadon       Celadon           NaN           NaN
# 2                  NaN       Taupe         Taupe           NaN           NaN
# 3                  NaN        Blue          Blue           NaN           NaN
# 4                  NaN      Silver        Silver           NaN           NaN
#
#    primary image filename                                  url primary image  \
# 0                     NaN                                                NaN
# 1                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url alternate image 1 url alternate image 2 url alternate image 3  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 4 url alternate image 5 url alternate image 6  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 7 url alternate image 8  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#                             url room setting image 1 url room setting image 2  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...                      NaN
# 4                                                NaN                      NaN
#
#   url room setting image 3 url drawing  url interactive 360 image  \
# 0                      NaN         NaN                        NaN
# 1                      NaN         NaN                        NaN
# 2                      NaN         NaN                        NaN
# 3                      NaN         NaN                        NaN
# 4                      NaN         NaN                        NaN
#
#   url animated gif                                  url product sheet  \
# 0              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url instruction sheet  url marketing sheet 1  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#                           url california label (jpg)  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#                           url california label (pdf)             item style  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
#
#        item substyle item substyle 2 item collection licensed by  \
# 0        Luxe / Glam             NaN         Obelisk         NaN
# 1  Country / Cottage             NaN       Porcelain         NaN
# 2       Scandinavian             NaN         Ceramic         NaN
# 3    Coastal / Beach             NaN  Recycled Glass         NaN
# 4        Luxe / Glam             NaN   Mercury Glass         NaN
#
#    carton count truck only  carton 1 width (inches)  carton 1 length (inches)  \
# 0           1.0         No                     19.0                      19.0
# 1           1.0         No                     18.2                      21.0
# 2           1.0         No                     12.0                      27.7
# 3           1.0         No                     21.0                      21.0
# 4           1.0         No                     18.2                      25.9
#
#    carton 1 height (inches)  carton 1 weight (pounds)  \
# 0                      34.0                      10.0
# 1                      18.2                      14.0
# 2                      12.0                      10.0
# 3                      23.0                      10.0
# 4                      18.2                      12.0
#
#    carton 1 volume (cubic feet)  carton 2 width (inches)  \
# 0                          7.10                      NaN
# 1                          4.03                      NaN
# 2                          2.31                      NaN
# 3                          5.87                      NaN
# 4                          4.96                      NaN
#
#    carton 2 length (inches)  carton 2 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 2 weight (pounds)  carton2volumecubicfeet  carton 3 width (inches)  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
#    carton 3 length (inches)  carton 3 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 3 weight (pounds)  carton 3 volume (cubic feet) ada compliant  \
# 0                       NaN                           NaN           NaN
# 1                       NaN                           NaN           NaN
# 2                       NaN                           NaN           NaN
# 3                       NaN                           NaN           NaN
# 4                       NaN                           NaN           NaN
#
#   available with eef conversion kit option title 24 compliant safety rating  \
# 0                 No                    No                NaN            UL
# 1                 No                    No                NaN            UL
# 2                 No                    No                NaN            UL
# 3                 No                    No                NaN            UL
# 4                 No                    No                NaN            UL
#
#   certified damp/wet  bulb 1 count  bulb 1 wattage bulb 1 type bulb 1 base  \
# 0                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 1                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 2                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 3                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 4                NaN           1.0           100.0   A21 3-Way  E26 Medium
#
#   bulb 1 included  bulb 2 count  bulb 2 wattage bulb 2 type bulb 2 base  \
# 0              No           NaN             NaN         NaN         NaN
# 1              No           NaN             NaN         NaN         NaN
# 2              No           NaN             NaN         NaN         NaN
# 3              No           NaN             NaN         NaN         NaN
# 4              No           NaN             NaN         NaN         NaN
#
#   bulb 2 included  led  total lumens color temperature  cri  voltage  \
# 0             NaN  NaN           NaN               NaN  NaN      NaN
# 1             NaN  NaN           NaN               NaN  NaN      NaN
# 2             NaN  NaN           NaN               NaN  NaN      NaN
# 3             NaN  NaN           NaN               NaN  NaN      NaN
# 4             NaN  NaN           NaN               NaN  NaN      NaN
#
#   switch type dimmable lamp base dimensions (inches)  \
# 0       3-Way      NaN                           NaN
# 1       3-Way      NaN                           NaN
# 2       3-Way      NaN                           NaN
# 3       3-Way      NaN                           NaN
# 4       3-Way      NaN                           NaN
#
#   backplate/canopy dimensions (inches) extension rods (inches)  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
#
#    min overall height (inches)  max overall height (inches)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    min extension (inches)  max extension (inches)  hcwo (inches)  \
# 0                     NaN                     NaN            NaN
# 1                     NaN                     NaN            NaN
# 2                     NaN                     NaN            NaN
# 3                     NaN                     NaN            NaN
# 4                     NaN                     NaN            NaN
#
#              shade/glass description shade/glass materials shade/glass finish  \
# 0  Round Hardback White Fabric Shade                Fabric              White
# 1        Round Hardback Burlap Shade                Burlap          Off-White
# 2         Round Hardback Linen Shade                 Linen              Brown
# 3  Round Hardback White Fabric Shade                Fabric              White
# 4  Round Hardback White Fabric Shade                Fabric              White
#
#    shade/glass width  shade/glass width at top (inches)  \
# 0                NaN                               16.0
# 1                NaN                               16.0
# 2                NaN                               10.0
# 3                NaN                               14.0
# 4                NaN                               16.0
#
#    shade/glass width at bottom (inches)  shade/glass height (inches)  \
# 0                                  18.0                         11.0
# 1                                  18.0                         11.0
# 2                                  10.0                         16.0
# 3                                  20.0                         11.0
# 4                                  18.0                         11.0
#
#   shade shape harp/spider cord color  cord length (inches)  \
# 0         NaN         NaN        NaN                  66.0
# 1         NaN         NaN        NaN                  66.0
# 2         NaN         NaN        NaN                  66.0
# 3         NaN         NaN        NaN                  66.0
# 4         NaN         NaN        NaN                  66.0
#
#    chain length (inches)  chain price ($) replacement glass price ($)  \
# 0                    NaN              NaN                         NaN
# 1                    NaN              NaN                         NaN
# 2                    NaN              NaN                         NaN
# 3                    NaN              NaN                         NaN
# 4                    NaN              NaN                         NaN
#
#    replacement crystal price ($)  mirror width (inches)  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#    mirror height (inches)  drawer count drawer 1 interior dimensions (inches)  \
# 0                     NaN           NaN                                   NaN
# 1                     NaN           NaN                                   NaN
# 2                     NaN           NaN                                   NaN
# 3                     NaN           NaN                                   NaN
# 4                     NaN           NaN                                   NaN
#
#   drawer 2 interior dimensions (inches) drawer 3 interior dimensions (inches)  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    furniture arm height (inches)  furniture seat height (inches)  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   furniture seat dimensions (inches)  furniture weight capacity (pounds)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   country of origin  primary catalog primary catalog page related items  \
# 0             China    ELK Home 2019                  529           NaN
# 1             China  Lamp Works 2016                   28           NaN
# 2             China  Lamp Works 2016                   36           NaN
# 3             China    ELK Home 2019                  517           NaN
# 4             China  Lamp Works 2016                   41           NaN
#
#                                            brand bio  \
# 0  Dimond Lighting is an award-winning designer a...
# 1  Dimond Lighting is an award-winning designer a...
# 2  Dimond Lighting is an award-winning designer a...
# 3  Dimond Lighting is an award-winning designer a...
# 4  Dimond Lighting is an award-winning designer a...
#
#                                         helpful tips    selling point 1  \
# 0  When choosing a table lamp it is important to ...   8-Inch wide base
# 1  When choosing a table lamp it is important to ...  12-Inch wide base
# 2  When choosing a table lamp it is important to ...  10-Inch wide base
# 3  When choosing a table lamp it is important to ...  14-Inch wide base
# 4  When choosing a table lamp it is important to ...   9-Inch wide base
#
#   selling point 2 selling point 3 selling point 4 selling point 5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    selling point 6  selling point 7  selling point 8  selling point 9  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    selling point 10 record status
# 0               NaN        Active
# 1               NaN        Active
# 2               NaN        Active
# 3               NaN        Active
# 4               NaN        Active

# %% [markdown]
# ## 2. Currency rounding to cent

# %% [markdown]
# ### Let's start with removing the "$" and ","  for the wholesale column

# %%
df['wholesale ($)'] = df['wholesale ($)'].astype(str)
df['wholesale ($)']
# Out:
# 0         228.0
# 1         229.5
# 2         201.0
# 3         151.5
# 4         219.0
#          ...
# 6665     $90.00
# 6666    $250.00
# 6667    $190.00
# 6668    $150.00
# 6669    $175.00
# Name: wholesale ($), Length: 6670, dtype: object

# %%
def normalize_number(str):
    if '$' in str:
        str = str.replace('$', '')
    if ',' in str:
        str = str.replace(',', '')
    return str

# %%
for index, row in df.iterrows():
    df.at[index, 'wholesale ($)'] = normalize_number(row['wholesale ($)'])

# %% [markdown]
# ### Round to two decimal places

# %%
df['wholesale ($)'] = df['wholesale ($)'].astype(float).map('{:.2f}'.format)

# %% [markdown]
# ### Map column

# %%
df['map ($)'] = df['map ($)'].astype(str)

# %%
for index, row in df.iterrows():
    df.at[index, 'map ($)'] = normalize_number(row['map ($)'])

# %%
df['map ($)'] = df['map ($)'].astype(float).map('{:.2f}'.format)

# %%
df.head()
# Out:
#   item number           upc  new item system creation date  min order qty  \
# 0         203  8.109370e+11       NaN           2015-07-07              1
# 1         205  8.109370e+11       NaN           2015-07-07              1
# 2         208  8.109370e+11       NaN           2015-07-07              1
# 3         210  8.109370e+11       NaN           2015-07-07              1
# 4         217  8.109370e+11       NaN           2015-07-07              1
#
#   sales uom wholesale ($) map ($) msrp ($)  \
# 0      Each        228.00  304.00  $456.00
# 1      Each        229.50  306.00  $459.00
# 2      Each        201.00  268.00  $402.00
# 3      Each        151.50  202.00  $303.00
# 4      Each        219.00  292.00  $438.00
#
#                                          description long description  \
# 0          White Obelisk Table Lamp With Night Light              NaN
# 1  Antiqued Porcelain Table Lamp In Celadon Crack...              NaN
# 2                 Bisque Ceramic Table Lamp In Taupe              NaN
# 3       Recycled Fluted Glass Urn Table Lamp In Blue              NaN
# 4          Fluted Mercury Glass Table Lamp In Silver              NaN
#
#              brand    item category   item type outdoor  item width (inches)  \
# 0  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 1  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
# 2  Dimond Lighting  Indoor Lighting  Table Lamp      No                 10.0
# 3  Dimond Lighting  Indoor Lighting  Table Lamp      No                 20.0
# 4  Dimond Lighting  Indoor Lighting  Table Lamp      No                 18.0
#
#    item depth (inches)  item height (inches)  item diameter (inches)  \
# 0                 18.0                  36.0                    18.0
# 1                 18.0                  31.0                    18.0
# 2                 10.0                  27.0                    10.0
# 3                 20.0                  25.0                    20.0
# 4                 18.0                  34.0                    18.0
#
#    item weight (pounds) multi-piece dimension 1 (inches)  \
# 0                   6.0                              NaN
# 1                  12.0                              NaN
# 2                   7.0                              NaN
# 3                   8.0                              NaN
# 4                  10.0                              NaN
#
#   multi-piece dimension 2 (inches) multi-piece dimension 3 (inches)  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   multi-piece dimension 4 (inches)           item materials  \
# 0                              NaN                    Glass
# 1                              NaN                  Ceramic
# 2                              NaN                  Ceramic
# 3                              NaN  Recycled Glass, Acrylic
# 4                              NaN                    Glass
#
#   primary color family item finish item finish 1 item finish 2 item finish 3  \
# 0                  NaN       White         White           NaN           NaN
# 1                  NaN     Celadon       Celadon           NaN           NaN
# 2                  NaN       Taupe         Taupe           NaN           NaN
# 3                  NaN        Blue          Blue           NaN           NaN
# 4                  NaN      Silver        Silver           NaN           NaN
#
#    primary image filename                                  url primary image  \
# 0                     NaN                                                NaN
# 1                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4                     NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url alternate image 1 url alternate image 2 url alternate image 3  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 4 url alternate image 5 url alternate image 6  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   url alternate image 7 url alternate image 8  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#                             url room setting image 1 url room setting image 2  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...                      NaN
# 4                                                NaN                      NaN
#
#   url room setting image 3 url drawing  url interactive 360 image  \
# 0                      NaN         NaN                        NaN
# 1                      NaN         NaN                        NaN
# 2                      NaN         NaN                        NaN
# 3                      NaN         NaN                        NaN
# 4                      NaN         NaN                        NaN
#
#   url animated gif                                  url product sheet  \
# 0              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4              NaN  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#   url instruction sheet  url marketing sheet 1  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#                           url california label (jpg)  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...
#
#                           url california label (pdf)             item style  \
# 0  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 1  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 2  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
# 3  https://s3-us-west-2.amazonaws.com/elk-assets/...            Traditional
# 4  https://s3-us-west-2.amazonaws.com/elk-assets/...  Modern / Contemporary
#
#        item substyle item substyle 2 item collection licensed by  \
# 0        Luxe / Glam             NaN         Obelisk         NaN
# 1  Country / Cottage             NaN       Porcelain         NaN
# 2       Scandinavian             NaN         Ceramic         NaN
# 3    Coastal / Beach             NaN  Recycled Glass         NaN
# 4        Luxe / Glam             NaN   Mercury Glass         NaN
#
#    carton count truck only  carton 1 width (inches)  carton 1 length (inches)  \
# 0           1.0         No                     19.0                      19.0
# 1           1.0         No                     18.2                      21.0
# 2           1.0         No                     12.0                      27.7
# 3           1.0         No                     21.0                      21.0
# 4           1.0         No                     18.2                      25.9
#
#    carton 1 height (inches)  carton 1 weight (pounds)  \
# 0                      34.0                      10.0
# 1                      18.2                      14.0
# 2                      12.0                      10.0
# 3                      23.0                      10.0
# 4                      18.2                      12.0
#
#    carton 1 volume (cubic feet)  carton 2 width (inches)  \
# 0                          7.10                      NaN
# 1                          4.03                      NaN
# 2                          2.31                      NaN
# 3                          5.87                      NaN
# 4                          4.96                      NaN
#
#    carton 2 length (inches)  carton 2 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 2 weight (pounds)  carton2volumecubicfeet  carton 3 width (inches)  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
#    carton 3 length (inches)  carton 3 height (inches)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    carton 3 weight (pounds)  carton 3 volume (cubic feet) ada compliant  \
# 0                       NaN                           NaN           NaN
# 1                       NaN                           NaN           NaN
# 2                       NaN                           NaN           NaN
# 3                       NaN                           NaN           NaN
# 4                       NaN                           NaN           NaN
#
#   available with eef conversion kit option title 24 compliant safety rating  \
# 0                 No                    No                NaN            UL
# 1                 No                    No                NaN            UL
# 2                 No                    No                NaN            UL
# 3                 No                    No                NaN            UL
# 4                 No                    No                NaN            UL
#
#   certified damp/wet  bulb 1 count  bulb 1 wattage bulb 1 type bulb 1 base  \
# 0                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 1                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 2                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 3                NaN           1.0           100.0   A21 3-Way  E26 Medium
# 4                NaN           1.0           100.0   A21 3-Way  E26 Medium
#
#   bulb 1 included  bulb 2 count  bulb 2 wattage bulb 2 type bulb 2 base  \
# 0              No           NaN             NaN         NaN         NaN
# 1              No           NaN             NaN         NaN         NaN
# 2              No           NaN             NaN         NaN         NaN
# 3              No           NaN             NaN         NaN         NaN
# 4              No           NaN             NaN         NaN         NaN
#
#   bulb 2 included  led  total lumens color temperature  cri  voltage  \
# 0             NaN  NaN           NaN               NaN  NaN      NaN
# 1             NaN  NaN           NaN               NaN  NaN      NaN
# 2             NaN  NaN           NaN               NaN  NaN      NaN
# 3             NaN  NaN           NaN               NaN  NaN      NaN
# 4             NaN  NaN           NaN               NaN  NaN      NaN
#
#   switch type dimmable lamp base dimensions (inches)  \
# 0       3-Way      NaN                           NaN
# 1       3-Way      NaN                           NaN
# 2       3-Way      NaN                           NaN
# 3       3-Way      NaN                           NaN
# 4       3-Way      NaN                           NaN
#
#   backplate/canopy dimensions (inches) extension rods (inches)  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
#
#    min overall height (inches)  max overall height (inches)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    min extension (inches)  max extension (inches)  hcwo (inches)  \
# 0                     NaN                     NaN            NaN
# 1                     NaN                     NaN            NaN
# 2                     NaN                     NaN            NaN
# 3                     NaN                     NaN            NaN
# 4                     NaN                     NaN            NaN
#
#              shade/glass description shade/glass materials shade/glass finish  \
# 0  Round Hardback White Fabric Shade                Fabric              White
# 1        Round Hardback Burlap Shade                Burlap          Off-White
# 2         Round Hardback Linen Shade                 Linen              Brown
# 3  Round Hardback White Fabric Shade                Fabric              White
# 4  Round Hardback White Fabric Shade                Fabric              White
#
#    shade/glass width  shade/glass width at top (inches)  \
# 0                NaN                               16.0
# 1                NaN                               16.0
# 2                NaN                               10.0
# 3                NaN                               14.0
# 4                NaN                               16.0
#
#    shade/glass width at bottom (inches)  shade/glass height (inches)  \
# 0                                  18.0                         11.0
# 1                                  18.0                         11.0
# 2                                  10.0                         16.0
# 3                                  20.0                         11.0
# 4                                  18.0                         11.0
#
#   shade shape harp/spider cord color  cord length (inches)  \
# 0         NaN         NaN        NaN                  66.0
# 1         NaN         NaN        NaN                  66.0
# 2         NaN         NaN        NaN                  66.0
# 3         NaN         NaN        NaN                  66.0
# 4         NaN         NaN        NaN                  66.0
#
#    chain length (inches)  chain price ($) replacement glass price ($)  \
# 0                    NaN              NaN                         NaN
# 1                    NaN              NaN                         NaN
# 2                    NaN              NaN                         NaN
# 3                    NaN              NaN                         NaN
# 4                    NaN              NaN                         NaN
#
#    replacement crystal price ($)  mirror width (inches)  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#    mirror height (inches)  drawer count drawer 1 interior dimensions (inches)  \
# 0                     NaN           NaN                                   NaN
# 1                     NaN           NaN                                   NaN
# 2                     NaN           NaN                                   NaN
# 3                     NaN           NaN                                   NaN
# 4                     NaN           NaN                                   NaN
#
#   drawer 2 interior dimensions (inches) drawer 3 interior dimensions (inches)  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    furniture arm height (inches)  furniture seat height (inches)  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   furniture seat dimensions (inches)  furniture weight capacity (pounds)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   country of origin  primary catalog primary catalog page related items  \
# 0             China    ELK Home 2019                  529           NaN
# 1             China  Lamp Works 2016                   28           NaN
# 2             China  Lamp Works 2016                   36           NaN
# 3             China    ELK Home 2019                  517           NaN
# 4             China  Lamp Works 2016                   41           NaN
#
#                                            brand bio  \
# 0  Dimond Lighting is an award-winning designer a...
# 1  Dimond Lighting is an award-winning designer a...
# 2  Dimond Lighting is an award-winning designer a...
# 3  Dimond Lighting is an award-winning designer a...
# 4  Dimond Lighting is an award-winning designer a...
#
#                                         helpful tips    selling point 1  \
# 0  When choosing a table lamp it is important to ...   8-Inch wide base
# 1  When choosing a table lamp it is important to ...  12-Inch wide base
# 2  When choosing a table lamp it is important to ...  10-Inch wide base
# 3  When choosing a table lamp it is important to ...  14-Inch wide base
# 4  When choosing a table lamp it is important to ...   9-Inch wide base
#
#   selling point 2 selling point 3 selling point 4 selling point 5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    selling point 6  selling point 7  selling point 8  selling point 9  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    selling point 10 record status
# 0               NaN        Active
# 1               NaN        Active
# 2               NaN        Active
# 3               NaN        Active
# 4               NaN        Active

# %% [markdown]
# ### Now the MSRP column

# %%
df['msrp ($)'] = df['msrp ($)'].astype(str)

# %%
for index, row in df.iterrows():
    df.at[index, 'msrp ($)'] = normalize_number(row['msrp ($)'])

# %%
df['map ($)'] = df['map ($)'].astype(float).map('{:.2f}'.format)

# %% [markdown]
# ## For dimensions without units, assume inches. Convert anything which isn't in inches to inches.

# %%
df.columns.to_list()
# Out:
# ['item number',
#  'upc',
#  'new item',
#  'system creation date',
#  'min order qty',
#  'sales uom',
#  'wholesale ($)',
#  'map ($)',
#  'msrp ($)',
#  'description',
#  'long description',
#  'brand',
#  'item category',
#  'item type',
#  'outdoor',
#  'item width (inches)',
#  'item depth (inches)',
#  'item height (inches)',
#  'item diameter (inches)',
#  'item weight (pounds)',
#  'multi-piece dimension 1 (inches)',
#  'multi-piece dimension 2 (inches)',
#  'multi-piece dimension 3 (inches)',
#  'multi-piece dimension 4 (inches)',
#  'item materials',
#  'primary color family',
#  'item finish',
#  'item finish 1',
#  'item finish 2',
#  'item finish 3',
#  'primary image filename',
#  'url primary image',
#  'url alternate image 1',
#  'url alternate image 2',
#  'url alternate image 3',
#  'url alternate image 4',
#  'url alternate image 5',
#  'url alternate image 6',
#  'url alternate image 7',
#  'url alternate image 8',
#  'url room setting image 1',
#  'url room setting image 2',
#  'url room setting image 3',
#  'url drawing',
#  'url interactive 360 image',
#  'url animated gif',
#  'url product sheet',
#  'url instruction sheet',
#  'url marketing sheet 1',
#  'url california label (jpg)',
#  'url california label (pdf)',
#  'item style',
#  'item substyle',
#  'item substyle 2',
#  'item collection',
#  'licensed by',
#  'carton count',
#  'truck only',
#  'carton 1 width (inches)',
#  'carton 1 length (inches)',
#  'carton 1 height (inches)',
#  'carton 1 weight (pounds)',
#  'carton_1_cubic_inches',
#  'carton 2 width (inches)',
#  'carton 2 length (inches)',
#  'carton 2 height (inches)',
#  'carton 2 weight (pounds)',
#  'carton_2_cubic_inches',
#  'carton 3 width (inches)',
#  'carton 3 length (inches)',
#  'carton 3 height (inches)',
#  'carton 3 weight (pounds)',
#  'carton_3_cubic_inches',
#  'ada compliant',
#  'available with eef',
#  'conversion kit option',
#  'title 24 compliant',
#  'safety rating',
#  'certified damp/wet',
#  'bulb 1 count',
#  'bulb 1 wattage',
#  'bulb 1 type',
#  'bulb 1 base',
#  'bulb 1 included',
#  'bulb 2 count',
#  'bulb 2 wattage',
#  'bulb 2 type',
#  'bulb 2 base',
#  'bulb 2 included',
#  'led',
#  'total lumens',
#  'color temperature',
#  'cri',
#  'voltage',
#  'switch type',
#  'dimmable',
#  'lamp base dimensions (inches)',
#  'backplate/canopy dimensions (inches)',
#  'extension rods (inches)',
#  'min overall height (inches)',
#  'max overall height (inches)',
#  'min extension (inches)',
#  'max extension (inches)',
#  'hcwo (inches)',
#  'shade/glass description',
#  'shade/glass materials',
#  'shade/glass finish',
#  'shade/glass width',
#  'shade/glass width at top (inches)',
#  'shade/glass width at bottom (inches)',
#  'shade/glass height (inches)',
#  'shade shape',
#  'harp/spider',
#  'cord color',
#  'cord length (inches)',
#  'chain length (inches)',
#  'chain price ($)',
#  'replacement glass price ($)',
#  'replacement crystal price ($)',
#  'mirror width (inches)',
#  'mirror height (inches)',
#  'drawer count',
#  'drawer 1 interior dimensions (inches)',
#  'drawer 2 interior dimensions (inches)',
#  'drawer 3 interior dimensions (inches)',
#  'furniture arm height (inches)',
#  'furniture seat height (inches)',
#  'furniture seat dimensions (inches)',
#  'furniture weight capacity (pounds)',
#  'country of origin',
#  'primary catalog',
#  'primary catalog page',
#  'related items',
#  'brand bio',
#  'helpful tips',
#  'selling point 1',
#  'selling point 2',
#  'selling point 3',
#  'selling point 4',
#  'selling point 5',
#  'selling point 6',
#  'selling point 7',
#  'selling point 8',
#  'selling point 9',
#  'selling point 10',
#  'record status']

# %%
cubic_feet_to_inches = 12 ** 3

# %%
df['carton 1 volume (cubic feet)'] = df['carton 1 volume (cubic feet)'] * cubic_feet_to_inches

# %%
df.rename(columns={'carton 1 volume (cubic feet)': 'carton_1_cubic_inches'}, inplace=True)

# %%
df['carton2volumecubicfeet'] = np.where(df['carton2volumecubicfeet'].notna(), df['carton2volumecubicfeet'] * cubic_feet_to_inches, df['carton2volumecubicfeet'])

# %%
df.rename(columns={'carton2volumecubicfeet': 'carton_2_cubic_inches'}, inplace=True)

# %%
df['carton 3 volume (cubic feet)'] = np.where(df['carton 3 volume (cubic feet)'].notna(), df['carton 3 volume (cubic feet)'] * cubic_feet_to_inches, df['carton 3 volume (cubic feet)'])

# %%
df.rename(columns={'carton 3 volume (cubic feet)': 'carton_3_cubic_inches'}, inplace=True)

# %% [markdown]
# ## For weights without units, assume pounds. Convert anything which isn't in pounds to pounds.

# %% [markdown]
# ## UPC / Gtin / EAN should be handled as strings

# %%
df.upc = df.upc.astype(str)
